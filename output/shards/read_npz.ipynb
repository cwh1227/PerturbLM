# %%
import numpy as np

path = "shard_00010.npz"

data = np.load(path)

print("包含的字段:", data.files)


display(data['text_data'][1000:1010])
display(data['gene_ids'])
display(data['bin_ids'])

# ['gene_ids', 'bin_ids', 'lengths', 'domain_id', 'sample_id', 'text_data', 'text_cols']
display(data['lengths'])

# text_cols=array([
#     'tissue',
#     'region',
#     'sampleType',
#     'compartment',
#     'cellType1',
#     'cellType2',
#     'majorCluster',
#     'subCluster',
#     'sex',
#     'age',
#     'perturbType',
#     'disease',
#     'drug',
#     'dose',
#     'time'
# ], dtype='<U20')
# Out:
# 包含的字段: ['gene_ids', 'bin_ids', 'lengths', 'domain_id', 'sample_id', 'text_data', 'text_cols']
# array([['lung', 'none', 'none', 'none', 'none', 'none', 'none', 'none',
#         'F', 'none', 'trt_cp', 'lung cancer', 'BRD-K19294102', '10',
#         '24h'],
#        ['lung', 'none', 'none', 'none', 'none', 'none', 'none', 'none',
#         'F', 'none', 'trt_cp', 'lung cancer', 'troglitazone', '20',
#         '24h'],
#        ['lung', 'none', 'none', 'none', 'none', 'none', 'none', 'none',
#         'F', 'none', 'trt_cp', 'lung cancer', 'troglitazone', '10',
#         '24h'],
#        ['lung', 'none', 'none', 'none', 'none', 'none', 'none', 'none',
#         'F', 'none', 'trt_cp', 'lung cancer', 'BRD-K77908171', '20',
#         '24h'],
#        ['lung', 'none', 'none', 'none', 'none', 'none', 'none', 'none',
#         'F', 'none', 'trt_cp', 'lung cancer', 'BRD-K77908171', '10',
#         '24h'],
#        ['lung', 'none', 'none', 'none', 'none', 'none', 'none', 'none',
# ...
